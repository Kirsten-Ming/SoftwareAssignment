# %%
# analysis.py
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
apartment=pd.read_csv('Ming_Kirsten-python_assignment2_orig.csv') 
print(apartment)
# Out:
#          _id      RSN  YEAR_REGISTERED  YEAR_EVALUATED  YEAR_BUILT  \
# 0          1  4304347              NaN             NaN      1999.0
# 1          2  5156815           2023.0             NaN      1973.0
# 2          3  5156814           2023.0             NaN      1973.0
# 3          4  5157421           2023.0             NaN      1973.0
# 4          5  5156871           2023.0             NaN      1973.0
# ...      ...      ...              ...             ...         ...
# 11755  11756  4155086           2017.0          2017.0      1955.0
# 11756  11757  4154249           2017.0          2017.0      1966.0
# 11757  11758  4154780           2017.0          2017.0      1960.0
# 11758  11759  4154262           2017.0          2017.0      1977.0
# 11759  11760  4152642           2017.0          2017.0      1964.0
#
#       PROPERTY_TYPE  WARD                  WARDNAME  \
# 0           PRIVATE     2          Etobicoke Centre
# 1              TCHC    17          Don Valley North
# 2              TCHC    17          Don Valley North
# 3              TCHC    17          Don Valley North
# 4              TCHC    17          Don Valley North
# ...             ...   ...                       ...
# 11755       PRIVATE     5         York South-Weston
# 11756       PRIVATE     7  Humber River-Black Creek
# 11757       PRIVATE    16           Don Valley East
# 11758       PRIVATE     7  Humber River-Black Creek
# 11759       PRIVATE    21        Scarborough Centre
#
#                                    SITE_ADDRESS  CONFIRMED_STOREYS  ...  \
# 0      ** CREATED IN ERROR ** 399 THE WEST MALL                 22  ...
# 1                            15 FIELD SPARROWAY                  4  ...
# 2                            13 FIELD SPARROWAY                  4  ...
# 3                              6 TREE SPARROWAY                  4  ...
# 4                              2 TREE SPARROWAY                  4  ...
# ...                                         ...                ...  ...
# 11755                             1720 KEELE ST                  4  ...
# 11756                              10 JAYZEL DR                  7  ...
# 11757                         1063 DON MILLS RD                  4  ...
# 11758                          10 SAN ROMANOWAY                 34  ...
# 11759                    1651 VICTORIA PARK AVE                  8  ...
#
#        EXTERIOR_WALKWAYS BALCONY_GUARDS  WATER_PEN_EXT_BLDG_ELEMENTS  \
# 0                    5.0            5.0                          5.0
# 1                    5.0            5.0                          4.0
# 2                    4.0            5.0                          4.0
# 3                    3.0            5.0                          4.0
# 4                    5.0            5.0                          4.0
# ...                  ...            ...                          ...
# 11755                4.0            4.0                          3.0
# 11756                3.0            3.0                          3.0
# 11757                3.0            2.0                          2.0
# 11758                3.0            3.0                          3.0
# 11759                4.0            4.0                          4.0
#
#       PARKING_AREA  OTHER_FACILITIES   GRID   LATITUDE  LONGITUDE           X  \
# 0              5.0               5.0  W0233  43.643781 -79.565456  299503.625
# 1              3.0               4.0  N1721  43.791143 -79.368820  315333.193
# 2              3.0               4.0  N1721  43.790920 -79.368771  315334.815
# 3              3.0               4.0  N1721  43.791384 -79.369630  315272.148
# 4              3.0               4.0  N1721  43.791511 -79.369045  315330.308
# ...            ...               ...    ...        ...        ...         ...
# 11755          5.0               NaN  W0536  43.685203 -79.473617  306911.453
# 11756          3.0               NaN  W0727  43.749340 -79.549430  300803.693
# 11757          4.0               NaN  N1627  43.735506 -79.342342  317484.175
# 11758          4.0               NaN  W0725  43.758540 -79.516681  303441.401
# 11759          3.0               NaN  E2131  43.732885 -79.305521  320451.154
#
#                  Y
# 0      4833538.964
# 1      4849916.905
# 2      4849906.373
# 3      4849932.515
# 4      4849947.465
# ...            ...
# 11755  4838139.002
# 11756  4845265.279
# 11757  4843740.129
# 11758  4846286.246
# 11759  4843454.222
#
# [11760 rows x 40 columns]

# %%
#Renaming one or more columns 
def clean_names(string):
    return string.lower()

apartment=apartment.rename(columns=clean_names)

# %%
# creating a new column 'storey_group', otherwise there would be too many columns
apartment['storeys_group'] = pd.cut(apartment['confirmed_storeys'], bins=[float('-inf'), 24, float('inf')], labels=['less than 25', '25 or more'], right=False)

# Grouped bar chart for 'score' by 'wardname' and 'storeys_group' using seaborn
plt.figure(figsize=(14, 8))
sns.barplot(data=apartment, x='wardname', y='score', hue='storeys_group')

# Adding labels, title, and legend
plt.xlabel('Ward Name')
plt.ylabel('Apartment Score')
plt.title('Apartment Score by Ward Name and Storeys Group')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Storeys Group')
# Save figures
plt.savefig('filename.png')
